# %%
#Importar a biblioteca pandas
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Automobile.csv")

# %%
#Visualizando as 5 primeiras linhas
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
#Renomeando coluna
df = df.rename(columns={"origin": "country"})

# %%
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year country
# 0    3504          12.0          70     usa
# 1    3693          11.5          70     usa
# 2    3436          11.0          70     usa
# 3    3433          12.0          70     usa
# 4    3449          10.5          70     usa

# %%
#Saber o total de linhas e colunas
df.shape
# Out:
# (398, 9)

# %%
df.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'country'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name             object
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# country          object
# dtype: object

# %%
df.tail(15)
# Out:
#                                   name   mpg  cylinders  displacement  \
# 383                        honda civic  38.0          4          91.0
# 384                 honda civic (auto)  32.0          4          91.0
# 385                      datsun 310 gx  38.0          4          91.0
# 386              buick century limited  25.0          6         181.0
# 387  oldsmobile cutlass ciera (diesel)  38.0          6         262.0
# 388         chrysler lebaron medallion  26.0          4         156.0
# 389                     ford granada l  22.0          6         232.0
# 390                   toyota celica gt  32.0          4         144.0
# 391                  dodge charger 2.2  36.0          4         135.0
# 392                   chevrolet camaro  27.0          4         151.0
# 393                    ford mustang gl  27.0          4         140.0
# 394                          vw pickup  44.0          4          97.0
# ...

# %%
#Informações estatística
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
#Aplicar filtro
df['country'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
japan = df.loc[df["country"] == "japan"]
japan.head()
# Out:
#                      name   mpg  cylinders  displacement  horsepower  weight  \
# 14  toyota corona mark ii  24.0          4         113.0        95.0    2372
# 18           datsun pl510  27.0          4          97.0        88.0    2130
# 29           datsun pl510  27.0          4          97.0        88.0    2130
# 31          toyota corona  25.0          4         113.0        95.0    2228
# 53    toyota corolla 1200  31.0          4          71.0        65.0    1773
#
#     acceleration  model_year country
# 14          15.0          70   japan
# 18          14.5          70   japan
# 29          14.5          71   japan
# 31          14.0          71   japan
# 53          19.0          71   japan

# %%
df.groupby("country")["name"].nunique()
# Out:
# country
# europe     58
# japan      60
# usa       187
# Name: name, dtype: int64

# %%
#Mostrar uma amostra
df.sample(5)
# Out:
#                                 name   mpg  cylinders  displacement  \
# 163                    plymouth fury  18.0          6         225.0
# 341               chevrolet citation  23.5          6         173.0
# 238                   dodge colt m/m  33.5          4          98.0
# 244  volkswagen rabbit custom diesel  43.1          4          90.0
# 1                  buick skylark 320  15.0          8         350.0
#
#      horsepower  weight  acceleration  model_year country
# 163        95.0    3785          19.0          75     usa
# 341       110.0    2725          12.6          81     usa
# 238        83.0    2075          15.9          77     usa
# 244        48.0    1985          21.5          78  europe
# 1         165.0    3693          11.5          70     usa

# %%
#Verificando os valores nulos
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# country         0
# dtype: int64

# %%
#Substituindo os valores nulos
df["horsepower"].fillna(0, inplace=True)

# %%
#Também podemos usar df.dropna(inplace=True) para deletar os valores nulos
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# country         0
# dtype: int64

# %%
#Mostrar os top 3
df.nlargest(3, "mpg")
# Out:
#                      name   mpg  cylinders  displacement  horsepower  weight  \
# 322             mazda glc  46.6          4          86.0        65.0    2110
# 329   honda civic 1500 gl  44.6          4          91.0        67.0    1850
# 325  vw rabbit c (diesel)  44.3          4          90.0        48.0    2085
#
#      acceleration  model_year country
# 322          17.9          80   japan
# 329          13.8          80   japan
# 325          21.7          80  europe

# %%
df.nsmallest(3, "mpg")
# Out:
#          name   mpg  cylinders  displacement  horsepower  weight  \
# 28   hi 1200d   9.0          8         304.0       193.0    4732
# 25  ford f250  10.0          8         360.0       215.0    4615
# 26  chevy c20  10.0          8         307.0       200.0    4376
#
#     acceleration  model_year country
# 28          18.5          70     usa
# 25          14.0          70     usa
# 26          15.0          70     usa

# %%
#Ordenar a tabela
df.sort_values("acceleration", ascending=False).head(10)
# Out:
#                                   name   mpg  cylinders  displacement  \
# 299                        peugeot 504  27.2          4         141.0
# 394                          vw pickup  44.0          4          97.0
# 326                 vw dasher (diesel)  43.4          4          90.0
# 59                   volkswagen type 3  23.0          4          97.0
# 300  oldsmobile cutlass salon brougham  23.9          8         260.0
# 195                 chevrolet chevette  29.0          4          85.0
# 196                    chevrolet woody  24.5          4          98.0
# 209                        peugeot 504  19.0          4         120.0
# 328                 mercedes-benz 240d  30.0          4         146.0
# 325               vw rabbit c (diesel)  44.3          4          90.0
#
#      horsepower  weight  acceleration  model_year country
# 299        71.0    3190          24.8          79  europe
# 394        52.0    2130          24.6          82  europe
# ...

# %%
#Visualização de dados
plt.style.use('bmh')
df["cylinders"].value_counts(ascending=True).plot.bar()
# Out:
# <Axes: xlabel='cylinders'>

# %%
df["country"].value_counts()
# Out:
# country
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
df["country"].value_counts().plot.pie(title="Country x qtde_car")
plt.xlabel("country")
plt.ylabel("qtde_car");
